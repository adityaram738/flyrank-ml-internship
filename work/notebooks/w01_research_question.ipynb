# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/adityaram738/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane and why
#
# I chose Lane 2: Refresh / Content Opportunity Scoring.
#
# This lane focuses on identifying webpages that should be reviewed first based on search performance signals. I chose it because it is practical, beginner-friendly, and aligns with the starter dataset provided in this internship. My goal is to build a decision-support system that helps prioritize pages for review rather than replacing human judgment.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# Research Question
# Can search performance data help identify webpages that should be reviewed first for content refresh?
#
# Decision
# Which pages should an SEO or content team review first?
#
# Action
# The team can prioritize high-risk pages for content updates, title improvements, metadata optimization, or monitoring.
#
# Cost of a wrong recommendation
# A false positive wastes time reviewing pages that do not need updates.
#
# A false negative means an important declining page could be ignored and lose additional traffic.
#
# Why ML?
# Machine learning can combine many search performance signals and help rank pages that deserve attention more effectively than simple rules alone.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", len(df))
print("Average CTR:", round(df["ctr"].mean(), 4))
print(df["content_type"].value_counts().head())
# Out:
# Rows: 30000
# Average CTR: 0.5107
# content_type
# keyword article       27207
# feedly article         2096
# comparison article      697
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This project identifies patterns observed in search performance data and provides decision-support recommendations.
#
# The results help prioritize pages for review, but they do not automatically determine which pages should be updated.
#
# This analysis does not prove that refreshing content causes better search performance, and it does not predict or explain Google's ranking algorithm.

# %%
print("Careful wording section completed.")
# Out:
# Careful wording section completed.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
